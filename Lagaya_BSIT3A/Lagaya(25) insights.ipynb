# %% [markdown]
# <h1> MoOoLiEeoOo <h1>
#
# <hr>
#
#  <h1> Patrick Lagaya <h1>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <p>Importing dataset to Jupyter notebook</p>
# <p>Converting Dataset to dataframe</p>

# %% [markdown]
# <h1>Requirements</h1>
# <p>name of the data frame</p>
# <p>source</p>

# %%
penguins = pd.read_csv("D:\datasets\\penguins.csv")

# %%
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# <h1>Descriptive Analytics</h1>

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
penguins.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                       75%     max
# bill_length_mm       48.5    59.6
# bill_depth_mm        18.7    21.5
# flipper_length_mm   213.0   231.0
# body_mass_g        4750.0  6300.0
# year               2009.0  2009.0

# %% [markdown]
# <h1>Cleaning the Data Row</h1>

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# <h3>Selecting a Column</h3>
# <h3>Syntax</h3>
#
# data frame ['column']

# %%
penguins['island']
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 3      Torgersen
# 4      Torgersen
#          ...
# 339        Dream
# 340        Dream
# 341        Dream
# 342        Dream
# 343        Dream
# Name: island, Length: 344, dtype: object

# %%
penguins['island'] == 'Dream'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: island, Length: 344, dtype: bool

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins[penguins["species"] == "Chisnrap"]
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %%
penguins[penguins["species"] == "Gentoo"]
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152  Gentoo  Biscoe            46.1           13.2              211.0
# 153  Gentoo  Biscoe            50.0           16.3              230.0
# 154  Gentoo  Biscoe            48.7           14.1              210.0
# 155  Gentoo  Biscoe            50.0           15.2              218.0
# 156  Gentoo  Biscoe            47.6           14.5              215.0
# ..      ...     ...             ...            ...                ...
# 271  Gentoo  Biscoe             NaN            NaN                NaN
# 272  Gentoo  Biscoe            46.8           14.3              215.0
# 273  Gentoo  Biscoe            50.4           15.7              222.0
# 274  Gentoo  Biscoe            45.2           14.8              212.0
# 275  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# 152       4500.0  female  2007
# 153       5700.0    male  2007
# ...

# %%
penguins[penguins["species"] == "Adelie"]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# ...

# %%
penguins[penguins["species"] == "Adelie"]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# ...

# %%
Adelie_df = penguins[penguins["species"] == "Adelie"]
Adelie_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# ...

# %%
penguins[penguins["species"] >= "Adelie"]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
penguins[penguins["body_mass_g"] >= 4000]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 7       Adelie  Torgersen            39.2           19.6              195.0
# 9       Adelie  Torgersen            42.0           20.2              190.0
# 14      Adelie  Torgersen            34.6           21.1              198.0
# 17      Adelie  Torgersen            42.5           20.7              197.0
# 19      Adelie  Torgersen            46.0           21.5              194.0
# ..         ...        ...             ...            ...                ...
# 323  Chinstrap      Dream            49.0           19.6              212.0
# 329  Chinstrap      Dream            50.7           19.7              203.0
# 333  Chinstrap      Dream            49.3           19.9              203.0
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
#
#      body_mass_g   sex  year
# ...

# %%
(penguins["species"] == "Adelie") & (penguins["body_mass_g"] >= 4000)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
penguins[(penguins["species"] == "Adelie") & (penguins["body_mass_g"] >= 4000)]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# 17   Adelie  Torgersen            42.5           20.7              197.0
# 19   Adelie  Torgersen            46.0           21.5              194.0
# 35   Adelie      Dream            39.2           21.1              196.0
# 39   Adelie      Dream            39.8           19.1              184.0
# 43   Adelie      Dream            44.1           19.7              196.0
# 45   Adelie      Dream            39.6           18.8              190.0
# 49   Adelie      Dream            42.3           21.2              191.0
# 51   Adelie     Biscoe            40.1           18.9              188.0
# 53   Adelie     Biscoe            42.0           19.5              200.0
# ...

# %%
Adelie_heavy = penguins[(penguins["species"] == "Adelie") & (penguins["body_mass_g"] >= 4000)]

# %%
Adelie_heavy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, 7 to 151
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            39 non-null     object
#  1   island             39 non-null     object
#  2   bill_length_mm     39 non-null     float64
#  3   bill_depth_mm      39 non-null     float64
#  4   flipper_length_mm  39 non-null     float64
#  5   body_mass_g        39 non-null     float64
#  6   sex                38 non-null     object
#  7   year               39 non-null     int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['bill_length_mm'].mean()
# Out:
# 43.9219298245614

# %%
penguins['bill_length_mm']
# Out:
# 0      39.1
# 1      39.5
# 2      40.3
# 3       NaN
# 4      36.7
#        ...
# 339    55.8
# 340    43.5
# 341    49.6
# 342    50.8
# 343    50.2
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
penguins['bill_length_mm'].fillna(penguins['bill_length_mm'].mean())
# Out:
# 0      39.10000
# 1      39.50000
# 2      40.30000
# 3      43.92193
# 4      36.70000
#          ...
# 339    55.80000
# 340    43.50000
# 341    49.60000
# 342    50.80000
# 343    50.20000
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins ['sex'] = penguins ['sex'].fillna(penguins ['sex'].mode())

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins ['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %% [markdown]
# <h1>How to change data type of a Column
# </h1>

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
penguins['species'] = penguins['species'].astype ('category')

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    category
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: category(1), float64(4), int64(1), object(2)
# memory usage: 19.4+ KB

# %%
penguins['year'] = penguins['year'].astype ('category')

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    category
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    category
# dtypes: category(2), float64(4), object(2)
# memory usage: 17.2+ KB

# %% [markdown]
# <h1>Exploratory Data Analyics</h1>

# %% [markdown]
# <h3>1. What are the median of bill_length_mm of every species?</h3>

# %%
Chinstrap_df = penguins[penguins["species"] == "Chinstrap"]
Chinstrap_df
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
Gentoo_df = penguins[penguins["species"] == "Gento0"]
Gentoo_df
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %%
Chinstrap_df['bill_length_mm'].median()
# Out:
# 49.55

# %%
Gentoo_df['bill_length_mm'].median()
# Out:
# nan

# %%
Adelie_df['bill_length_mm'].median()
# Out:
# 38.8

# %% [markdown]
# <h3>Apparently, The median of those 3 are different from each other. For Chinstrap it is 49 </h3>

# %% [markdown]
# <h3> 2. In those 3 species who has the highest value counts?</h3>

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %% [markdown]
# <h3>The results tell that Adelie has the highest value count</h3>

# %% [markdown]
# <h3>3. How many Adelie are below in 4000kg?</h3>

# %%
penguins['body_mass_g'] <= 4000
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 339     True
# 340     True
# 341     True
# 342    False
# 343     True
# Name: body_mass_g, Length: 344, dtype: bool

# %% [markdown]
# <h3> 4. Which species has the longest flipper_lenght?</h3>

# %%
Chinstrap_df['flipper_length_mm'].mean()
# Out:
# 195.8235294117647

# %%
Gentoo_df['flipper_length_mm'].mean()
# Out:
# nan

# %%
Adelie_df['flipper_length_mm'].mean()
# Out:
# 189.95364238410596

# %% [markdown]
# As we can see, the data shows that chinstrap has  longest flipper_lenght among the three species

# %% [markdown]
# <h1>5. Which species has the highest number of species?</h1>

# %%
PerIsland = penguins.groupby(['species'])['island'].count()

# %%
PerIsland
# Out:
# species
# Adelie       152
# Chinstrap     68
# Gentoo       124
# Name: island, dtype: int64

# %% [markdown]
# As we can see above Adelie has the highest number species

# %% [markdown]
# <h1>6. How many living species per island? </h1>

# %%
PerIsland = penguins.groupby(['species', 'island']).count()

# %%
PerIsland
# Out:
#                      bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species   island
# Adelie    Biscoe                 44             44                 44
#           Dream                  56             56                 56
#           Torgersen              51             51                 51
# Chinstrap Dream                  68             68                 68
# Gentoo    Biscoe                123            123                123
#
#                      body_mass_g  sex  year
# species   island
# Adelie    Biscoe              44   44    44
#           Dream               56   55    56
#           Torgersen           51   47    52
# Chinstrap Dream               68   68    68
# Gentoo    Biscoe             123  119   124

# %% [markdown]
# as we navigate the data above we can see that there are three species living there and the adelie species has three different types

# %% [markdown]
# <h1>7. Identify the list of year of every species in the data </h1>

# %%
PerIsland = penguins.groupby(['species', 'island', 'year']).size()

# %%
PerIsland
# Out:
# species    island     year
# Adelie     Biscoe     2007    10
#                       2008    18
#                       2009    16
#            Dream      2007    20
#                       2008    16
#                       2009    20
#            Torgersen  2007    20
#                       2008    16
#                       2009    16
# Chinstrap  Dream      2007    26
#                       2008    18
#                       2009    24
# Gentoo     Biscoe     2007    34
#                       2008    46
#                       2009    44
# dtype: int64

# %% [markdown]
# as we can see above this are the following years where the species has been added in the data above

# %%
PerIsland = penguins.groupby(['species', 'island'])['body_mass_g'].count()

# %%
PerIsland
# Out:
# species    island
# Adelie     Biscoe        44
#            Dream         56
#            Torgersen     51
# Chinstrap  Dream         68
# Gentoo     Biscoe       123
# Name: body_mass_g, dtype: int64

# %% [markdown]
# <h1>TESTING CORRELATION
# </h1>

# %% [markdown]
# <h3>Pearson R Correlation</h3>

# %% [markdown]
# <h5>Used for testing correlation between two NUMERICAL VALUES</h5>

# %%
weight_flipper_cor = penguins['body_mass_g'].corr(penguins['flipper_length_mm'])

# %%
weight_flipper_cor
# Out:
# 0.8712017673060113
